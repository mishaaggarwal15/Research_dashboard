# %%
pip install scholarly
# Out:
# Collecting scholarly
#   Downloading scholarly-1.4.1-py3-none-any.whl (29 kB)
# Collecting selenium
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
#      |████████████████████████████████| 904 kB 14.7 MB/s
# Collecting sphinx-rtd-theme
#   Downloading sphinx_rtd_theme-1.0.0-py2.py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 63.8 MB/s
# Collecting free-proxy
#   Downloading free_proxy-1.0.3.tar.gz (4.0 kB)
# Collecting arrow
#   Downloading arrow-1.1.1-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 8.3 MB/s
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from scholarly) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from scholarly) (2.23.0)
# Collecting stem
#   Downloading stem-1.8.0.tar.gz (2.9 MB)
#      |████████████████████████████████| 2.9 MB 45.7 MB/s
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Requirement already satisfied: PySocks in /usr/local/lib/python3.7/dist-packages (from scholarly) (1.7.1)
# Collecting python-dotenv
#   Downloading python_dotenv-0.19.0-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from scholarly) (3.7.4.3)
# Collecting bibtexparser
#   Downloading bibtexparser-1.2.0.tar.gz (46 kB)
#      |████████████████████████████████| 46 kB 4.9 MB/s
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.7/dist-packages (from arrow->scholarly) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.0->arrow->scholarly) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.7/dist-packages (from bibtexparser->scholarly) (2.4.7)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from bibtexparser->scholarly) (0.16.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from free-proxy->scholarly) (4.2.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->scholarly) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->scholarly) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->scholarly) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->scholarly) (2.10)
# Collecting cryptography>=1.3.4
#   Downloading cryptography-35.0.0-cp36-abi3-manylinux_2_24_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 55.7 MB/s
# Collecting pyOpenSSL>=0.14
#   Downloading pyOpenSSL-21.0.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.1 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->requests[socks]->scholarly) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->requests[socks]->scholarly) (2.20)
# Requirement already satisfied: docutils<0.18 in /usr/local/lib/python3.7/dist-packages (from sphinx-rtd-theme->scholarly) (0.17.1)
# Requirement already satisfied: sphinx>=1.6 in /usr/local/lib/python3.7/dist-packages (from sphinx-rtd-theme->scholarly) (1.8.5)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.6->sphinx-rtd-theme->scholarly) (1.2.0)
# Requirement already satisfied: sphinxcontrib-websupport in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.6->sphinx-rtd-theme->scholarly) (1.2.4)
# Requirement already satisfied: babel!=2.0,>=1.3 in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.6->sphinx-rtd-theme->scholarly) (2.9.1)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.6->sphinx-rtd-theme->scholarly) (2.11.3)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.6->sphinx-rtd-theme->scholarly) (0.7.12)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.6->sphinx-rtd-theme->scholarly) (2.6.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.6->sphinx-rtd-theme->scholarly) (21.0)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.6->sphinx-rtd-theme->scholarly) (2.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from sphinx>=1.6->sphinx-rtd-theme->scholarly) (57.4.0)
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.7/dist-packages (from babel!=2.0,>=1.3->sphinx>=1.6->sphinx-rtd-theme->scholarly) (2018.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.3->sphinx>=1.6->sphinx-rtd-theme->scholarly) (2.0.1)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.7/dist-packages (from sphinxcontrib-websupport->sphinx>=1.6->sphinx-rtd-theme->scholarly) (1.1.5)
# Building wheels for collected packages: bibtexparser, fake-useragent, free-proxy, stem
#   Building wheel for bibtexparser (setup.py) ... done
#   Created wheel for bibtexparser: filename=bibtexparser-1.2.0-py3-none-any.whl size=36711 sha256=9decbb01a2dcc7901414be8d33f9fbbbf9c4465cd47974f183fd3cce23250b79
#   Stored in directory: /root/.cache/pip/wheels/3e/13/1d/09c37a40f39ddd7b226719a797f1896a5b95d730de27e7a505
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=60c745c74ff68f84967020c22e61c863955bb031daf243d3e47563d8699babd4
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
#   Building wheel for free-proxy (setup.py) ... done
#   Created wheel for free-proxy: filename=free_proxy-1.0.3-py3-none-any.whl size=4252 sha256=4d434b0abe2881acde61cf7f7a0838c6bfa9ba81dcb15d6dd13d21c78fdaf5cc
#   Stored in directory: /root/.cache/pip/wheels/42/ed/ae/127aff63212a6fa36dc5e774c51a1ac570c2d977dce86a81df
#   Building wheel for stem (setup.py) ... done
#   Created wheel for stem: filename=stem-1.8.0-py3-none-any.whl size=436050 sha256=9d0c9e24ba6e6b12e21af0db5fdbf911d970cd360e158220297f3250bb8a1254
#   Stored in directory: /root/.cache/pip/wheels/77/73/98/4f0966106838e9a11710b56790f413ce6ae62e78257f8653c9
# Successfully built bibtexparser fake-useragent free-proxy stem
# Installing collected packages: cryptography, pyOpenSSL, stem, sphinx-rtd-theme, selenium, python-dotenv, free-proxy, fake-useragent, bibtexparser, arrow, scholarly
# Successfully installed arrow-1.1.1 bibtexparser-1.2.0 cryptography-35.0.0 fake-useragent-0.1.11 free-proxy-1.0.3 pyOpenSSL-21.0.0 python-dotenv-0.19.0 scholarly-1.4.1 selenium-3.141.0 sphinx-rtd-theme-1.0.0 stem-1.8.0

# %%
from scholarly import scholarly
import pandas as pd
# Out:
# Error occurred during loading data. Trying to use cache server https://fake-useragent.herokuapp.com/browsers/0.1.11
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/fake_useragent/utils.py", line 154, in load
#     for item in get_browsers(verify_ssl=verify_ssl):
#   File "/usr/local/lib/python3.7/dist-packages/fake_useragent/utils.py", line 99, in get_browsers
#     html = html.split('<table class="w3-table-all notranslate">')[1]
# IndexError: list index out of range

# %%
df1 = pd.read_excel('/content/CSED.xlsx')
df2 = pd.read_excel('/content/CSED_derabassi.xlsx')
df3 = pd.read_excel('/content/Chemical.xlsx')
df4 = pd.read_excel('/content/Electrical & Instrumentation.xlsx')
df5 = pd.read_excel('/content/Electronics & Communication.xlsx')
df6 = pd.read_excel('/content/Mechanical.xlsx')
df7 = pd.read_excel('/content/biotech.xlsx')
df8 = pd.read_excel('/content/civil.xlsx')
df9 = pd.read_excel('/content/distant_edu.xlsx')

# %%
import re
l = [df1, df2, df3, df4, df5, df6, df7, df8, df9]
prefixes = ['Mr', 'Dr', 'Mrs','Ms']
regex = r'\b(?:' + '|'.join(prefixes) + ')\.\s*'
def name_update(j):
  j = re.sub(regex,'',j)
  return j

for i in l:
  i['Name'] = i['Name'].apply(lambda x: name_update(x))
print(l)

# %%
d = {}
l = [df1, df2, df3, df4, df5, df6, df7, df8, df9]

x = 1
for i in l:
  d["dept{0}".format(x)] = i['Name']
  x = x+1
print(d)
# Out:
# {'dept1': 0         R. K. Sharma
# 1           Seema Bawa
# 2         Rajesh Kumar
# 3      Inderveer Chana
# 4       Maninder Singh
#             ...
# 86         Sanjeev Rao
# 87          Tanya Garg
# 88         Amrita Kaur
# 89        Chinu Singla
# 90    Harmandeep Singh
# Name: Name, Length: 91, dtype: object, 'dept2': 0           AK Verma
# 1    Manisha Kaushal
# 2      Abhishek Jain
# 3        Vivek Gupta
# 4          Deep Mann
# Name: Name, dtype: object, 'dept3': 0               Rajeev Mehta
# 1     Dasaroju Gangacharyulu
# 2            Haripada Bhunia
# 3            Raj Kumar Gupta
# 4         Sanghamitra Barman
# 5        Sanjeev Kumar Ahuja
# 6       Jai Prakash Kushwaha
# 7            Avinash Chandra
# 8         Sudhir Kumar Singh
# 9                Neetu Singh
# 10           Parminder Singh
# 11        Rakesh Kumar Gupta
# Name: Name, dtype: object, 'dept4': 0                  R. S. Kaler
# 1               Smarajit Ghosh
# 2             Ravinder Agarwal
# 3                Mandeep Singh
# 4                  Sanjay Jain
# 5                  Manbir Kaur
# 6           Sunil Kumar Singla
# 7                 Mukesh Singh
# 8             Saurabh Bhardwaj
# 9               Gagandeep Kaur
# 10             Mandeep Singh-2
# 11              S. K. Aggarwal
# 12               Deepti Mittal
# 13                Nitin Narang
# 14              Parag Nijhawan
# 15             Prasenjit Basak
# 16                  S. Prakash
# 17           Vishal Srivastava
# 18              Jainy Sachdeva
# 19           Nirbhow Jap Singh
# 20                Amrita Sinha
# 21                Manoj Badoni
# 22                Shakti Singh
# 23               Suman Bhullar
# 24              Souvik Ganguli
# 25            Moon Inder Singh
# 26             Sangeeta Kamboj
# 27               Santosh Sonar
# 28                      Vikram
# 29                Swati Sondhi
# 30                Sahaj Saxena
# 31                 Pawan Kumar
# 32                Yogesh Tatte
# 33         Krishna Kumar Gupta
# 34    Venkata Karteek Yanumula
# 35               Sridhar Joshi
# 36              Sandeep Pandey
# 37               Ruchika Lamba
# 38                Navdeep Kaur
# 39              Shailesh Kumar
# 40            Jitender Kaushal
# 41             Gyanendra Singh
# 42                 Amrita Soni
# 43            Mohd. Asim Aftab
# 44                  AMIT KUMAR
# 45     Diwakar Prasad Tripathi
# 46                     Manaswi
# 47                Tanu Wadhera
# 48                 Abhisek Pal
# 49                Teena Narang
# 50            Deba Prasad Dash
# 51        Anjanee Kumar Mishra
# 52                Santanu Paul
# 53              Saurabh Shukla
# Name: Name, dtype: object, 'dept5': 0                  Alpana Agarwal
# 1                     R. S. Kaler
# 2                   Rajesh Khanna
# 3                   Sanjay Sharma
# 4                    Kulbir Singh
# 5                Amit Kumar Kohli
# 6                      Ravi Kumar
# 7                    Sanjay Kumar
# 8                  Hem Dutt Joshi
# 9                   Surbhi Sharma
# 10               Mayank Kumar Rai
# 11                 Urvinder Singh
# 12                  Hardeep Singh
# 13                    Vinay Kumar
# 14           Ashutosh Kumar Singh
# 15                  Ankush Kansal
# 16              Rana Pratap Yadav
# 17                    Manu Bansal
# 18                    Ajay Kakkar
# 19                    Amit Mishra
# 20                     Anil Arora
# 21           Karmjit Singh Sandha
# 22                   Neeru Jindal
# 23                 Amanpreet Kaur
# 24               Rishikesh Pandey
# 25                Sudhanshu Tyagi
# 26                  Mohit Agarwal
# 27                 Amanpreet Kaur
# 28                 Harpreet Vohra
# 29                 Rahul Upadhyay
# 30             Hari Shankar Singh
# 31                     Sumit Vyas
# 32            Arun Kr. Chatterjee
# 33                 Jaswinder Kaur
# 34                     Anil Singh
# 35             Shireesh Kumar Rai
# 36                    Amit Munjal
# 37                    Bharat Garg
# 38              Sujit Kumar Patel
# 39                Debabrata Ghosh
# 40                Pravindra Kumar
# 41                Rajneesh Sharma
# 42                 Navneet Sharma
# 43                 Mayank Agarwal
# 44                   Poonam Verma
# 45    Gitanjali Chandwani Manocha
# 46                         Dinesh
# 47             Subiman Chatterjee
# 48               Sukhwinder Kumar
# 49                    Geetika Dua
# 50                Gaganpreet Kaur
# 51                     Shashikant
# 52            Ram Kishan Dewangan
# 53                   Shubhra Jain
# 54                    Punit Kumar
# 55               Vinay K. Trivedi
# Name: Name, dtype: object, 'dept6': 0                 S. K. Mohapatra
# 1           Professor Ajay Batish
# 2                Tarun Kumar Bera
# 3                   A. S. Jawanda
# 4                   Sumeet Sharma
# 5                 Supreet Bhullar
# 6                     Vinod Kumar
# 7                     S.S.Mallick
# 8                     Tarun Nanda
# 9           Jaswinder Singh Saini
# 10                     Vivek Jain
# 11                  Dheeraj Gupta
# 12           Sandeep Kumar Sharma
# 13                  Ashish Singla
# 14            Madhup Kumar Mittal
# 15              Anant Kumar Singh
# 16            Ravinder Kr. Duvedi
# 17               Hiralal Bhowmick
# 18                Vikrant Khullar
# 19                 Kishore Khanna
# 20                 Devender Kumar
# 21                     Kundan Lal
# 22               Bikramjit Sharma
# 23                  Daljeet Singh
# 24              Vineet Srivastava
# 25                  Neeraj Grover
# 26                   Neeraj Kumar
# 27                    Deepak Jain
# 28                 Ashish Purohit
# 29             Gagandeep Bhardwaj
# 30                     Anu Mittal
# 31             Rohit Kumar Singla
# 32                   Deepa Mudgal
# 33                   Gautam Setia
# 34           Ravinder Singh Joshi
# 35          Amandeep Singh Oberoi
# 36                   Sachin Singh
# 37                 Rajendra Kumar
# 38    Dr  Ratnesh Kumar Raj Singh
# 39                    Sayan Sadhu
# 40            Satish Kumar Sharma
# 41            Rajesh Kumar Shukla
# 42                   Vishal Gupta
# 43                 Jaskaran Singh
# 44           Jay Prakash Tripathi
# 45                    A.M. Gadade
# 46        P Kalyan Chakravarthy K
# 47                    Atul Sharma
# 48                  Rajmeet Singh
# 49                   Pankaj Kumar
# 50                Sumit Chaudhary
# 51            Prabhat Chand Yadav
# 52                Rajnish Mallick
# 53                  Anshul Sharma
# 54                   Hitesh Kumar
# 55          Arindam Bhattacharjee
# Name: Name, dtype: object, 'dept7': 0               M S Reddy
# 1           Das, N. (Dr,)
# 2            Dinesh Goyal
# 3           Sanjai Saxena
# 4                 M Ghosh
# 5              Anil Kumar
# 6          Manoj Baranwal
# 7        Siddharth Sharma
# 8             Vikas Handa
# 9           M. Vasundhara
# 10    Atul Kumar Upadhyay
# 11     Ovais Shafiq Qadri
# 12          Priyankar Dey
# 13        Debajyoti Dutta
# 14            Nishu Joshi
# 15    Prangya Ranjan Rout
# Name: Name, dtype: object, 'dept8': 0        Prem Pal Bansal
# 1         Rafat Siddique
# 2          Naveen Kwatra
# 3          Sarbjit Singh
# 4          Rajesh Pathak
# 5           Shweta Goyal
# 6          Shruti Sharma
# 7     Dwarika Nath Ratha
# 8         Tapas Karmaker
# 9           Richa Babbar
# 10            Neena Garg
# 11          Tanuj Chopra
# 12           Gurbir Kaur
# 13        Danie Roy A. B
# 14          Heaven Singh
# 15        Aditya Parihar
# 16       Himanshu Chawla
# 17     Trishna Choudhury
# 18         Govind Gaurav
# 19        Manpreet Singh
# 20           Reema Goyal
# 21           Vivek Gupta
# 22       Abhishek Sharma
# 23           Kumari Monu
# 24       Parvinder Singh
# Name: Name, dtype: object, 'dept9': 0    Rajesh Khanna
# Name: Name, dtype: object}

# %%
def checkKey(dict, key): 
    if key in dict.keys():
        return 1
    else:
        return 0

# %% [markdown]
# ## trial code

# %%
total_count = []

for i in (d['dept3']):
  try:
    search_query = scholarly.search_author(i)
    author = scholarly.fill(next(search_query))
    author = author['publications']
  except StopIteration:
    pass

  papers_count = {"Title":[],"year":[]};
  for i in range(len(author)):
    if checkKey(author[i]['bib'], 'pub_year'):
      if checkKey(author[i]['bib'], 'title'):
        papers_count["Title"].append(author[i]['bib']['title'])
        papers_count["year"].append(author[i]['bib']['pub_year'])

  #print(papers_count)

  ## Datafame of the publications and dates of a faculity member: 
  df = pd.DataFrame.from_dict(papers_count, orient='index')
  df = df.transpose()
  # print(df)
  df = df.sort_values(by = 'year', ascending = False)
  # print(df)

  #count for yearly publications:
  i = 0
  a = [i+1 if x > '2020' else i for x in df.year]
  # print(a)
  count = 0
  for i in a:
    if i>0:
      count = count+1
  print(count)
  total_count.append(count)
# Out:
# 0
# 2
# 20
# 1
# 1
# 1
# 2
# 3
# 0
# 3
# 25
# 2

# %%
print(total_count)
# Out:
# [0, 2, 20, 1, 1, 1, 2, 3, 0, 3, 25, 2]

# %% [markdown]
# ## trial code

# %%
total_count = []

for i in (d['dept1']):
  search_query = scholarly.search_author(i)
  author = scholarly.fill(next(search_query))
  author = author['publications']

  papers_count = {"Title":[],"year":[]};
  for i in range(len(author)):
    if checkKey(author[i]['bib'], 'pub_year'):
      if checkKey(author[i]['bib'], 'title'):
        papers_count["Title"].append(author[i]['bib']['title'])
        papers_count["year"].append(author[i]['bib']['pub_year'])

  #print(papers_count)

  ## Datafame of the publications and dates of a faculity member: 
  df = pd.DataFrame.from_dict(papers_count, orient='index')
  df = df.transpose()
  # print(df)
  df = df.sort_values(by = 'year', ascending = False)
  # print(df)

  #count for yearly publications:
  i = 0
  a = [i+1 if x > '2020' else i for x in df.year]
  # print(a)
  count = 0
  for i in a:
    if i>0:
      count = count+1
  print(count)
  total_count.append(count)

# %% [markdown]
# ## final CODE

# %%
p = 0
## for loop outside main code:
for k in d:
  total_count = []
  for i in d[k]:
    try:
      search_query = scholarly.search_author(i)
      author = scholarly.fill(next(search_query))
      author = author['publications']
    except StopIteration:
      pass

    papers_count = {"Title":[],"year":[]};
    for i in range(len(author)):
      if checkKey(author[i]['bib'], 'pub_year'):
        if checkKey(author[i]['bib'], 'title'):
          papers_count["Title"].append(author[i]['bib']['title'])
          papers_count["year"].append(author[i]['bib']['pub_year'])

    #print(papers_count)

    ## Datafame of the publications and dates of a faculity member: 
    df = pd.DataFrame.from_dict(papers_count, orient='index')
    df = df.transpose()
    # print(df)
    df = df.sort_values(by = 'year', ascending = False)
    # print(df)

    #count for yearly publications:
    i = 0
    a = [i+1 if x > '2020' else i for x in df.year]
    # print(a)
    count = 0
    for i in a:
      if i>0:
        count = count+1
    print(count)
    total_count.append(count)
  m = l[p]
  m['count'] = total_count
  m.to_csv('/content/sample_data/modified_data/'+str(p))
  p = p + 1
  print(total_count)
  print(m)
# Out:
# 0
# 11
# 4
# 7
# 0
# 3
# 1
# 23
# 11
# 5
# 0
# 2
# 9
# 93
# 2
# 1
# 5
# 7
# 0
# 2
# 1
# 1
# 8
# 3
# 2
# 2
# 1
# 3
# 4
# 4
# 24
# 6
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# 6
# 0
# 1
# 4
# 12
# 2
# 5
# 2
# 0
# 2
# 2
# 0
# 4
# 25
# 1
# 3
# 0
# 0
# 1
# 0
# 0
# 1
# 4
# 43
# 9
# 1
# 0
# 0
# 6
# 5
# 2
# 2
# 1
# 0
# 2
# 0
# 1
# 0
# 2
# 0
# 36
# 0
# 1
# 0
# 0
# 0
# 2
# 0
# 3
# 1
# 0
# 4
# 5
# 3
# 0
# 0
# 14
# 14
# 0
# [0, 11, 4, 7, 0, 3, 1, 23, 11, 5, 0, 2, 9, 93, 2, 1, 5, 7, 0, 2, 1, 1, 8, 3, 2, 2, 1, 3, 4, 4, 24, 6, 6, 0, 1, 4, 12, 2, 5, 2, 0, 2, 2, 0, 4, 25, 1, 3, 0, 0, 1, 0, 0, 1, 4, 43, 9, 1, 0, 0, 6, 5, 2, 2, 1, 0, 2, 0, 1, 0, 2, 0, 36, 0, 1, 0, 0, 0, 2, 0, 3, 1, 0, 4, 5, 3, 0, 0, 14, 14, 0]
#                 Name  ... count
# 0       R. K. Sharma  ...     0
# 1         Seema Bawa  ...    11
# 2       Rajesh Kumar  ...     4
# 3    Inderveer Chana  ...     7
# 4     Maninder Singh  ...     0
# ..               ...  ...   ...
# 86       Sanjeev Rao  ...     0
# 87        Tanya Garg  ...     0
# 88       Amrita Kaur  ...    14
# 89      Chinu Singla  ...    14
# 90  Harmandeep Singh  ...     0
#
# [91 rows x 5 columns]
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# 27
# 1
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# 0
# 59
# 0
# [27, 1, 0, 59, 0]
#               Name  ... count
# 0         AK Verma  ...    27
# 1  Manisha Kaushal  ...     1
# 2    Abhishek Jain  ...     0
# 3      Vivek Gupta  ...    59
# 4        Deep Mann  ...     0
#
# [5 rows x 5 columns]
# 0
# 2
# 20
# 1
# 1
# 1
# 2
# 3
# 0
# 3
# 25
# 2
# [0, 2, 20, 1, 1, 1, 2, 3, 0, 3, 25, 2]
#                       Name  ... count
# 0             Rajeev Mehta  ...     0
# 1   Dasaroju Gangacharyulu  ...     2
# 2          Haripada Bhunia  ...    20
# 3          Raj Kumar Gupta  ...     1
# 4       Sanghamitra Barman  ...     1
# 5      Sanjeev Kumar Ahuja  ...     1
# 6     Jai Prakash Kushwaha  ...     2
# 7          Avinash Chandra  ...     3
# 8       Sudhir Kumar Singh  ...     0
# 9              Neetu Singh  ...     3
# 10         Parminder Singh  ...    25
# 11      Rakesh Kumar Gupta  ...     2
#
# [12 rows x 5 columns]
# 9
# 5
# 16
# 1
# 15
# 15
# 15
# 3
# 5
# 15
# 15
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# 18
# 3
# 4
# 15
# 10
# 9
# 3
# 3
# 2
# 0
# 8
# 1
# 1
# 27
# 27
# 0
# 2
# 52
# 1
# 4
# 20
# 3
# 4
# 0
# 0
# 15
# 15
# 43
# 1
# 0
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# 43
# 2
# 2
# 1
# 1
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# 0
# 6
# 0
# 0
# 0
# 7
# 4
# 1
# [9, 5, 16, 1, 15, 15, 15, 3, 5, 15, 15, 18, 3, 4, 15, 10, 9, 3, 3, 2, 0, 8, 1, 1, 27, 27, 0, 2, 52, 1, 4, 20, 3, 4, 0, 0, 15, 15, 43, 1, 0, 43, 2, 2, 1, 1, 0, 6, 0, 0, 0, 7, 4, 1]
#                         Name  ... count
# 0                R. S. Kaler  ...     9
# 1             Smarajit Ghosh  ...     5
# 2           Ravinder Agarwal  ...    16
# 3              Mandeep Singh  ...     1
# 4                Sanjay Jain  ...    15
# 5                Manbir Kaur  ...    15
# 6         Sunil Kumar Singla  ...    15
# 7               Mukesh Singh  ...     3
# 8           Saurabh Bhardwaj  ...     5
# 9             Gagandeep Kaur  ...    15
# 10           Mandeep Singh-2  ...    15
# 11            S. K. Aggarwal  ...    18
# 12             Deepti Mittal  ...     3
# 13              Nitin Narang  ...     4
# 14            Parag Nijhawan  ...    15
# 15           Prasenjit Basak  ...    10
# 16                S. Prakash  ...     9
# 17         Vishal Srivastava  ...     3
# 18            Jainy Sachdeva  ...     3
# 19         Nirbhow Jap Singh  ...     2
# 20              Amrita Sinha  ...     0
# 21              Manoj Badoni  ...     8
# 22              Shakti Singh  ...     1
# 23             Suman Bhullar  ...     1
# 24            Souvik Ganguli  ...    27
# 25          Moon Inder Singh  ...    27
# 26           Sangeeta Kamboj  ...     0
# 27             Santosh Sonar  ...     2
# 28                    Vikram  ...    52
# 29              Swati Sondhi  ...     1
# 30              Sahaj Saxena  ...     4
# 31               Pawan Kumar  ...    20
# 32              Yogesh Tatte  ...     3
# 33       Krishna Kumar Gupta  ...     4
# 34  Venkata Karteek Yanumula  ...     0
# 35             Sridhar Joshi  ...     0
# 36            Sandeep Pandey  ...    15
# 37             Ruchika Lamba  ...    15
# 38              Navdeep Kaur  ...    43
# 39            Shailesh Kumar  ...     1
# 40          Jitender Kaushal  ...     0
# 41           Gyanendra Singh  ...    43
# 42               Amrita Soni  ...     2
# 43          Mohd. Asim Aftab  ...     2
# 44                AMIT KUMAR  ...     1
# 45   Diwakar Prasad Tripathi  ...     1
# 46                   Manaswi  ...     0
# 47              Tanu Wadhera  ...     6
# 48               Abhisek Pal  ...     0
# 49              Teena Narang  ...     0
# 50          Deba Prasad Dash  ...     0
# 51      Anjanee Kumar Mishra  ...     7
# 52              Santanu Paul  ...     4
# 53            Saurabh Shukla  ...     1
#
# [54 rows x 5 columns]
# 0
# 9
# 22
# 36
# 3
# 3
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# 20
# 26
# 3
# 1
# 1
# 2
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# 40
# 26
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# 27
# 27
# 3
# 0
# 4
# 50
# 0
# 0
# 0
# 82
# 7
# 9
# 8
# 82
# 82
# 0
# 3
# 3
# 0
# 1
# 0
# 8
# 1
# 9
# 4
# 3
# 0
# 2
# 2
# 0
# 11
# 11
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# 194
# 0
# 1
# 8
# 0
# 89
# 0
# 2
# 8
# 0
# [0, 9, 22, 36, 3, 3, 20, 26, 3, 1, 1, 2, 40, 26, 27, 27, 3, 0, 4, 50, 0, 0, 0, 82, 7, 9, 8, 82, 82, 0, 3, 3, 0, 1, 0, 8, 1, 9, 4, 3, 0, 2, 2, 0, 11, 11, 194, 0, 1, 8, 0, 89, 0, 2, 8, 0]
#                            Name  ... count
# 0                Alpana Agarwal  ...     0
# 1                   R. S. Kaler  ...     9
# 2                 Rajesh Khanna  ...    22
# 3                 Sanjay Sharma  ...    36
# 4                  Kulbir Singh  ...     3
# 5              Amit Kumar Kohli  ...     3
# 6                    Ravi Kumar  ...    20
# 7                  Sanjay Kumar  ...    26
# 8                Hem Dutt Joshi  ...     3
# 9                 Surbhi Sharma  ...     1
# 10             Mayank Kumar Rai  ...     1
# 11               Urvinder Singh  ...     2
# 12                Hardeep Singh  ...    40
# 13                  Vinay Kumar  ...    26
# 14         Ashutosh Kumar Singh  ...    27
# 15                Ankush Kansal  ...    27
# 16            Rana Pratap Yadav  ...     3
# 17                  Manu Bansal  ...     0
# 18                  Ajay Kakkar  ...     4
# 19                  Amit Mishra  ...    50
# 20                   Anil Arora  ...     0
# 21         Karmjit Singh Sandha  ...     0
# 22                 Neeru Jindal  ...     0
# 23               Amanpreet Kaur  ...    82
# 24             Rishikesh Pandey  ...     7
# 25              Sudhanshu Tyagi  ...     9
# 26                Mohit Agarwal  ...     8
# 27               Amanpreet Kaur  ...    82
# 28               Harpreet Vohra  ...    82
# 29               Rahul Upadhyay  ...     0
# 30           Hari Shankar Singh  ...     3
# 31                   Sumit Vyas  ...     3
# 32          Arun Kr. Chatterjee  ...     0
# 33               Jaswinder Kaur  ...     1
# 34                   Anil Singh  ...     0
# 35           Shireesh Kumar Rai  ...     8
# 36                  Amit Munjal  ...     1
# 37                  Bharat Garg  ...     9
# 38            Sujit Kumar Patel  ...     4
# 39              Debabrata Ghosh  ...     3
# 40              Pravindra Kumar  ...     0
# 41              Rajneesh Sharma  ...     2
# 42               Navneet Sharma  ...     2
# 43               Mayank Agarwal  ...     0
# 44                 Poonam Verma  ...    11
# 45  Gitanjali Chandwani Manocha  ...    11
# 46                       Dinesh  ...   194
# 47           Subiman Chatterjee  ...     0
# 48             Sukhwinder Kumar  ...     1
# 49                  Geetika Dua  ...     8
# 50              Gaganpreet Kaur  ...     0
# 51                   Shashikant  ...    89
# 52          Ram Kishan Dewangan  ...     0
# 53                 Shubhra Jain  ...     2
# 54                  Punit Kumar  ...     8
# 55             Vinay K. Trivedi  ...     0
#
# [56 rows x 5 columns]
# 2
# 2
# 3
# 0
# 1
# 1
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# 53
# 3
# 9
# 9
# 0
# 1
# 2
# 8
# 2
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# 9
# 9
# 9
# 4
# 0
# 2
# 9
# 1
# 1
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# 3
# 5
# 1
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# 0
# 0
# 1
# 1
# 3
# 5
# 0
# 9
# 6
# 1
# 0
# 0
# 0
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# 18
# 16
# 16
# 2
# 3
# 1
# 0
# 4
# 2
# 1
# 0
# 1
# 0
# 1
# 7
# 1
# [2, 2, 3, 0, 1, 1, 53, 3, 9, 9, 0, 1, 2, 8, 2, 9, 9, 9, 4, 0, 2, 9, 1, 1, 3, 5, 1, 0, 0, 1, 1, 3, 5, 0, 9, 6, 1, 0, 0, 0, 18, 16, 16, 2, 3, 1, 0, 4, 2, 1, 0, 1, 0, 1, 7, 1]
#                            Name  ... count
# 0               S. K. Mohapatra  ...     2
# 1         Professor Ajay Batish  ...     2
# 2              Tarun Kumar Bera  ...     3
# 3                 A. S. Jawanda  ...     0
# 4                 Sumeet Sharma  ...     1
# 5               Supreet Bhullar  ...     1
# 6                   Vinod Kumar  ...    53
# 7                   S.S.Mallick  ...     3
# 8                   Tarun Nanda  ...     9
# 9         Jaswinder Singh Saini  ...     9
# 10                   Vivek Jain  ...     0
# 11                Dheeraj Gupta  ...     1
# 12         Sandeep Kumar Sharma  ...     2
# 13                Ashish Singla  ...     8
# 14          Madhup Kumar Mittal  ...     2
# 15            Anant Kumar Singh  ...     9
# 16          Ravinder Kr. Duvedi  ...     9
# 17             Hiralal Bhowmick  ...     9
# 18              Vikrant Khullar  ...     4
# 19               Kishore Khanna  ...     0
# 20               Devender Kumar  ...     2
# 21                   Kundan Lal  ...     9
# 22             Bikramjit Sharma  ...     1
# 23                Daljeet Singh  ...     1
# 24            Vineet Srivastava  ...     3
# 25                Neeraj Grover  ...     5
# 26                 Neeraj Kumar  ...     1
# 27                  Deepak Jain  ...     0
# 28               Ashish Purohit  ...     0
# 29           Gagandeep Bhardwaj  ...     1
# 30                   Anu Mittal  ...     1
# 31           Rohit Kumar Singla  ...     3
# 32                 Deepa Mudgal  ...     5
# 33                 Gautam Setia  ...     0
# 34         Ravinder Singh Joshi  ...     9
# 35        Amandeep Singh Oberoi  ...     6
# 36                 Sachin Singh  ...     1
# 37               Rajendra Kumar  ...     0
# 38  Dr  Ratnesh Kumar Raj Singh  ...     0
# 39                  Sayan Sadhu  ...     0
# 40          Satish Kumar Sharma  ...    18
# 41          Rajesh Kumar Shukla  ...    16
# 42                 Vishal Gupta  ...    16
# 43               Jaskaran Singh  ...     2
# 44         Jay Prakash Tripathi  ...     3
# 45                  A.M. Gadade  ...     1
# 46      P Kalyan Chakravarthy K  ...     0
# 47                  Atul Sharma  ...     4
# 48                Rajmeet Singh  ...     2
# 49                 Pankaj Kumar  ...     1
# 50              Sumit Chaudhary  ...     0
# 51          Prabhat Chand Yadav  ...     1
# 52              Rajnish Mallick  ...     0
# 53                Anshul Sharma  ...     1
# 54                 Hitesh Kumar  ...     7
# 55        Arindam Bhattacharjee  ...     1
#
# [56 rows x 5 columns]
# 10
# 5
# 4
# 6
# 0
# 8
# 7
# 2
# 0
# 2
# 1
# 1
# 'geckodriver' executable needs to be in PATH.
# Fetching only the top 20 coauthors
# 7
# 15
# 1
# 8
# [10, 5, 4, 6, 0, 8, 7, 2, 0, 2, 1, 1, 7, 15, 1, 8]
#                    Name  ... count
# 0             M S Reddy  ...    10
# 1         Das, N. (Dr,)  ...     5
# 2          Dinesh Goyal  ...     4
# 3         Sanjai Saxena  ...     6
# 4               M Ghosh  ...     0
# 5            Anil Kumar  ...     8
# 6        Manoj Baranwal  ...     7
# 7      Siddharth Sharma  ...     2
# 8           Vikas Handa  ...     0
# 9         M. Vasundhara  ...     2
# 10  Atul Kumar Upadhyay  ...     1
# 11   Ovais Shafiq Qadri  ...     1
# 12        Priyankar Dey  ...     7
# 13      Debajyoti Dutta  ...    15
# 14          Nishu Joshi  ...     1
# 15  Prangya Ranjan Rout  ...     8
#
# [16 rows x 5 columns]
# 8
# 13
# 13
# 2
# 20
# 10
# 1
# 4
# 0
# 0
# 0
# 0
# 1
# 1
# 0
# 0
# 2
# 1
# 1
# 0
# 1
# 59
# 126
# 0
# 3
# [8, 13, 13, 2, 20, 10, 1, 4, 0, 0, 0, 0, 1, 1, 0, 0, 2, 1, 1, 0, 1, 59, 126, 0, 3]
#                   Name  ... count
# 0      Prem Pal Bansal  ...     8
# 1       Rafat Siddique  ...    13
# 2        Naveen Kwatra  ...    13
# 3        Sarbjit Singh  ...     2
# 4        Rajesh Pathak  ...    20
# 5         Shweta Goyal  ...    10
# 6        Shruti Sharma  ...     1
# 7   Dwarika Nath Ratha  ...     4
# 8       Tapas Karmaker  ...     0
# 9         Richa Babbar  ...     0
# 10          Neena Garg  ...     0
# 11        Tanuj Chopra  ...     0
# 12         Gurbir Kaur  ...     1
# 13      Danie Roy A. B  ...     1
# 14        Heaven Singh  ...     0
# 15      Aditya Parihar  ...     0
# 16     Himanshu Chawla  ...     2
# 17   Trishna Choudhury  ...     1
# 18       Govind Gaurav  ...     1
# 19      Manpreet Singh  ...     0
# 20         Reema Goyal  ...     1
# 21         Vivek Gupta  ...    59
# 22     Abhishek Sharma  ...   126
# 23         Kumari Monu  ...     0
# 24     Parvinder Singh  ...     3
#
# [25 rows x 5 columns]
# 22
# [22]
#             Name     int-desc  ...         int-desc 3 count
# 0  Rajesh Khanna  Coordinator  ...  rkhanna@thapr.edu    22
#
# [1 rows x 5 columns]

# %%
print(l)
# Out:
# [                Name  ... count
# 0       R. K. Sharma  ...     0
# 1         Seema Bawa  ...    11
# 2       Rajesh Kumar  ...     4
# 3    Inderveer Chana  ...     7
# 4     Maninder Singh  ...     0
# ..               ...  ...   ...
# 86       Sanjeev Rao  ...     0
# 87        Tanya Garg  ...     0
# 88       Amrita Kaur  ...    14
# 89      Chinu Singla  ...    14
# 90  Harmandeep Singh  ...     0
#
# [91 rows x 5 columns],               Name  ... count
# 0         AK Verma  ...    27
# 1  Manisha Kaushal  ...     1
# 2    Abhishek Jain  ...     0
# 3      Vivek Gupta  ...    59
# 4        Deep Mann  ...     0
#
# [5 rows x 5 columns],                       Name  ... count
# 0             Rajeev Mehta  ...     0
# 1   Dasaroju Gangacharyulu  ...     2
# 2          Haripada Bhunia  ...    20
# 3          Raj Kumar Gupta  ...     1
# 4       Sanghamitra Barman  ...     1
# 5      Sanjeev Kumar Ahuja  ...     1
# 6     Jai Prakash Kushwaha  ...     2
# 7          Avinash Chandra  ...     3
# 8       Sudhir Kumar Singh  ...     0
# 9              Neetu Singh  ...     3
# 10         Parminder Singh  ...    25
# 11      Rakesh Kumar Gupta  ...     2
#
# [12 rows x 5 columns],                         Name  ... count
# 0                R. S. Kaler  ...     9
# 1             Smarajit Ghosh  ...     5
# 2           Ravinder Agarwal  ...    16
# 3              Mandeep Singh  ...     1
# 4                Sanjay Jain  ...    15
# 5                Manbir Kaur  ...    15
# 6         Sunil Kumar Singla  ...    15
# 7               Mukesh Singh  ...     3
# 8           Saurabh Bhardwaj  ...     5
# 9             Gagandeep Kaur  ...    15
# 10           Mandeep Singh-2  ...    15
# 11            S. K. Aggarwal  ...    18
# 12             Deepti Mittal  ...     3
# 13              Nitin Narang  ...     4
# 14            Parag Nijhawan  ...    15
# 15           Prasenjit Basak  ...    10
# 16                S. Prakash  ...     9
# 17         Vishal Srivastava  ...     3
# 18            Jainy Sachdeva  ...     3
# 19         Nirbhow Jap Singh  ...     2
# 20              Amrita Sinha  ...     0
# 21              Manoj Badoni  ...     8
# 22              Shakti Singh  ...     1
# 23             Suman Bhullar  ...     1
# 24            Souvik Ganguli  ...    27
# 25          Moon Inder Singh  ...    27
# 26           Sangeeta Kamboj  ...     0
# 27             Santosh Sonar  ...     2
# 28                    Vikram  ...    52
# 29              Swati Sondhi  ...     1
# 30              Sahaj Saxena  ...     4
# 31               Pawan Kumar  ...    20
# 32              Yogesh Tatte  ...     3
# 33       Krishna Kumar Gupta  ...     4
# 34  Venkata Karteek Yanumula  ...     0
# 35             Sridhar Joshi  ...     0
# 36            Sandeep Pandey  ...    15
# 37             Ruchika Lamba  ...    15
# 38              Navdeep Kaur  ...    43
# 39            Shailesh Kumar  ...     1
# 40          Jitender Kaushal  ...     0
# 41           Gyanendra Singh  ...    43
# 42               Amrita Soni  ...     2
# 43          Mohd. Asim Aftab  ...     2
# 44                AMIT KUMAR  ...     1
# 45   Diwakar Prasad Tripathi  ...     1
# 46                   Manaswi  ...     0
# 47              Tanu Wadhera  ...     6
# 48               Abhisek Pal  ...     0
# 49              Teena Narang  ...     0
# 50          Deba Prasad Dash  ...     0
# 51      Anjanee Kumar Mishra  ...     7
# 52              Santanu Paul  ...     4
# 53            Saurabh Shukla  ...     1
#
# [54 rows x 5 columns],                            Name  ... count
# 0                Alpana Agarwal  ...     0
# 1                   R. S. Kaler  ...     9
# 2                 Rajesh Khanna  ...    22
# 3                 Sanjay Sharma  ...    36
# 4                  Kulbir Singh  ...     3
# 5              Amit Kumar Kohli  ...     3
# 6                    Ravi Kumar  ...    20
# 7                  Sanjay Kumar  ...    26
# 8                Hem Dutt Joshi  ...     3
# 9                 Surbhi Sharma  ...     1
# 10             Mayank Kumar Rai  ...     1
# 11               Urvinder Singh  ...     2
# 12                Hardeep Singh  ...    40
# 13                  Vinay Kumar  ...    26
# 14         Ashutosh Kumar Singh  ...    27
# 15                Ankush Kansal  ...    27
# 16            Rana Pratap Yadav  ...     3
# 17                  Manu Bansal  ...     0
# 18                  Ajay Kakkar  ...     4
# 19                  Amit Mishra  ...    50
# 20                   Anil Arora  ...     0
# 21         Karmjit Singh Sandha  ...     0
# 22                 Neeru Jindal  ...     0
# 23               Amanpreet Kaur  ...    82
# 24             Rishikesh Pandey  ...     7
# 25              Sudhanshu Tyagi  ...     9
# 26                Mohit Agarwal  ...     8
# 27               Amanpreet Kaur  ...    82
# 28               Harpreet Vohra  ...    82
# 29               Rahul Upadhyay  ...     0
# 30           Hari Shankar Singh  ...     3
# 31                   Sumit Vyas  ...     3
# 32          Arun Kr. Chatterjee  ...     0
# 33               Jaswinder Kaur  ...     1
# 34                   Anil Singh  ...     0
# 35           Shireesh Kumar Rai  ...     8
# 36                  Amit Munjal  ...     1
# 37                  Bharat Garg  ...     9
# 38            Sujit Kumar Patel  ...     4
# 39              Debabrata Ghosh  ...     3
# 40              Pravindra Kumar  ...     0
# 41              Rajneesh Sharma  ...     2
# 42               Navneet Sharma  ...     2
# 43               Mayank Agarwal  ...     0
# 44                 Poonam Verma  ...    11
# 45  Gitanjali Chandwani Manocha  ...    11
# 46                       Dinesh  ...   194
# 47           Subiman Chatterjee  ...     0
# 48             Sukhwinder Kumar  ...     1
# 49                  Geetika Dua  ...     8
# 50              Gaganpreet Kaur  ...     0
# 51                   Shashikant  ...    89
# 52          Ram Kishan Dewangan  ...     0
# 53                 Shubhra Jain  ...     2
# 54                  Punit Kumar  ...     8
# 55             Vinay K. Trivedi  ...     0
#
# [56 rows x 5 columns],                            Name  ... count
# 0               S. K. Mohapatra  ...     2
# 1         Professor Ajay Batish  ...     2
# 2              Tarun Kumar Bera  ...     3
# 3                 A. S. Jawanda  ...     0
# 4                 Sumeet Sharma  ...     1
# 5               Supreet Bhullar  ...     1
# 6                   Vinod Kumar  ...    53
# 7                   S.S.Mallick  ...     3
# 8                   Tarun Nanda  ...     9
# 9         Jaswinder Singh Saini  ...     9
# 10                   Vivek Jain  ...     0
# 11                Dheeraj Gupta  ...     1
# 12         Sandeep Kumar Sharma  ...     2
# 13                Ashish Singla  ...     8
# 14          Madhup Kumar Mittal  ...     2
# 15            Anant Kumar Singh  ...     9
# 16          Ravinder Kr. Duvedi  ...     9
# 17             Hiralal Bhowmick  ...     9
# 18              Vikrant Khullar  ...     4
# 19               Kishore Khanna  ...     0
# 20               Devender Kumar  ...     2
# 21                   Kundan Lal  ...     9
# 22             Bikramjit Sharma  ...     1
# 23                Daljeet Singh  ...     1
# 24            Vineet Srivastava  ...     3
# 25                Neeraj Grover  ...     5
# 26                 Neeraj Kumar  ...     1
# 27                  Deepak Jain  ...     0
# 28               Ashish Purohit  ...     0
# 29           Gagandeep Bhardwaj  ...     1
# 30                   Anu Mittal  ...     1
# 31           Rohit Kumar Singla  ...     3
# 32                 Deepa Mudgal  ...     5
# 33                 Gautam Setia  ...     0
# 34         Ravinder Singh Joshi  ...     9
# 35        Amandeep Singh Oberoi  ...     6
# 36                 Sachin Singh  ...     1
# 37               Rajendra Kumar  ...     0
# 38  Dr  Ratnesh Kumar Raj Singh  ...     0
# 39                  Sayan Sadhu  ...     0
# 40          Satish Kumar Sharma  ...    18
# 41          Rajesh Kumar Shukla  ...    16
# 42                 Vishal Gupta  ...    16
# 43               Jaskaran Singh  ...     2
# 44         Jay Prakash Tripathi  ...     3
# 45                  A.M. Gadade  ...     1
# 46      P Kalyan Chakravarthy K  ...     0
# 47                  Atul Sharma  ...     4
# 48                Rajmeet Singh  ...     2
# 49                 Pankaj Kumar  ...     1
# 50              Sumit Chaudhary  ...     0
# 51          Prabhat Chand Yadav  ...     1
# 52              Rajnish Mallick  ...     0
# 53                Anshul Sharma  ...     1
# 54                 Hitesh Kumar  ...     7
# 55        Arindam Bhattacharjee  ...     1
#
# [56 rows x 5 columns],                    Name  ... count
# 0             M S Reddy  ...    10
# 1         Das, N. (Dr,)  ...     5
# 2          Dinesh Goyal  ...     4
# 3         Sanjai Saxena  ...     6
# 4               M Ghosh  ...     0
# 5            Anil Kumar  ...     8
# 6        Manoj Baranwal  ...     7
# 7      Siddharth Sharma  ...     2
# 8           Vikas Handa  ...     0
# 9         M. Vasundhara  ...     2
# 10  Atul Kumar Upadhyay  ...     1
# 11   Ovais Shafiq Qadri  ...     1
# 12        Priyankar Dey  ...     7
# 13      Debajyoti Dutta  ...    15
# 14          Nishu Joshi  ...     1
# 15  Prangya Ranjan Rout  ...     8
#
# [16 rows x 5 columns],                   Name  ... count
# 0      Prem Pal Bansal  ...     8
# 1       Rafat Siddique  ...    13
# 2        Naveen Kwatra  ...    13
# 3        Sarbjit Singh  ...     2
# 4        Rajesh Pathak  ...    20
# 5         Shweta Goyal  ...    10
# 6        Shruti Sharma  ...     1
# 7   Dwarika Nath Ratha  ...     4
# 8       Tapas Karmaker  ...     0
# 9         Richa Babbar  ...     0
# 10          Neena Garg  ...     0
# 11        Tanuj Chopra  ...     0
# 12         Gurbir Kaur  ...     1
# 13      Danie Roy A. B  ...     1
# 14        Heaven Singh  ...     0
# 15      Aditya Parihar  ...     0
# 16     Himanshu Chawla  ...     2
# 17   Trishna Choudhury  ...     1
# 18       Govind Gaurav  ...     1
# 19      Manpreet Singh  ...     0
# 20         Reema Goyal  ...     1
# 21         Vivek Gupta  ...    59
# 22     Abhishek Sharma  ...   126
# 23         Kumari Monu  ...     0
# 24     Parvinder Singh  ...     3
#
# [25 rows x 5 columns],             Name     int-desc  ...         int-desc 3 count
# 0  Rajesh Khanna  Coordinator  ...  rkhanna@thapr.edu    22
#
# [1 rows x 5 columns]]

# %% [markdown]
# sum of count column for each dataframe

# %%
a = []
for i in l:
  m = i['count'].sum()
  a.append(m)

# %%
print(a)
# Out:
# [477, 87, 60, 472, 933, 248, 77, 266, 22]

# %% [markdown]
# now run new data only and let the old un-run
